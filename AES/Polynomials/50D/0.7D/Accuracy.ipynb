# %%
from __future__ import print_function
import torch
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import torch.utils.data
import torch.nn.init as init
from torch import nn, optim
from torch.autograd import Variable
from torch.nn import functional as F
from torchvision import datasets, transforms
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import pyDOE
from scipy import stats
import sys
import scipy.stats.distributions as dist
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
from sklearn.gaussian_process.kernels import DotProduct
from sklearn import preprocessing
from sklearn.svm import SVR
from collections import namedtuple
from sklearn.linear_model import ElasticNet
import sklearn
from sklearn.preprocessing import PolynomialFeatures

print( 'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# torch: 1.3.0+cpu cuda: False

# %% [markdown]
# ## Start Dimensionality Reduction Related Code

# %% [markdown]
# ## Load & Re-Scale Data Sets

# %%
""" Give the path to the training input files as the function argument, the function loads and rescales the initial data set"""
def load_rescale_data_sets(path):
    train_data = pd.read_csv(path, index_col=0).iloc[:,:-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_data = pd.read_csv(path[:-42]+str('Test_Data_Sets\\test_2_200Samples.csv'), index_col=0).iloc[:,:-1]
    cols = test_data.columns
    scalar = MinMaxScaler().fit(train_data)
    train_data = pd.DataFrame(scalar.transform (train_data)) 
    test_data = pd.DataFrame(scalar.transform (test_data)) 
    train_data.columns, test_data.columns = cols, cols
    return train_data, test_data

# %% [markdown]
# ## Autoencoders

# %%
""" Class Autoencoders, which implements the Autoencoders Neural Networks for Dimensionality Reduction """
class AE(nn.Module):
    
    def __init__(self, x_dim, z_dim):
        super(AE, self).__init__()
        
        self.x_dim = x_dim
        self.z_dim = z_dim
        
        self.h1_dim = int (self.x_dim - (1/5) * (self.x_dim - self.z_dim))
        self.h2_dim = int (self.x_dim - (2/5) * (self.x_dim - self.z_dim))
        self.h3_dim = int (self.x_dim - (3/5) * (self.x_dim - self.z_dim))
        self.h4_dim = int (self.x_dim - (4/5) * (self.x_dim - self.z_dim))

        #encoder
        self.enc = nn.Sequential( nn.Linear(self.x_dim , self.h1_dim), nn.Tanh(),
                                nn.Linear(self.h1_dim , self.h2_dim), nn.Tanh(),
                                nn.Linear(self.h2_dim , self.h3_dim), nn.Tanh(),
                                nn.Linear(self.h3_dim , self.h4_dim), nn.Tanh())
        
        self.enc_exact = nn.Sequential( nn.Linear(self.h4_dim, self.z_dim) )
        
        #decoder
        
        self.dec = nn.Sequential(nn.Linear(self.z_dim , self.h4_dim), nn.Tanh(),
                                nn.Linear(self.h4_dim , self.h3_dim), nn.Tanh(),
                                nn.Linear(self.h3_dim , self.h2_dim), nn.Tanh(),
                                nn.Linear(self.h2_dim , self.h1_dim), nn.Tanh())
                                
        self.dec_exact = nn.Sequential( nn.Linear( self.h1_dim, self.x_dim ))


    def encode (self, x ):
        enc = self.enc(x.float())
        enc_exact = self.enc_exact(enc)
        return enc_exact


    def decode (self, z):
        dec = self.dec(z)
        dec_exact = self.dec_exact(dec)
        return dec_exact

    def forward(self, x):
        loss = 0
        criterion = nn.MSELoss()
        #encoder
        enc = self.encode(x)
        #decoder
        dec = self.decode(enc)
        loss += criterion(dec, x.float())  
        return loss, enc, dec

# %% [markdown]
# ## Train and Test the AE

# %%
""" Functions to Implement the Training and Testing of AEs, Based on Methods in Autoencoder Class"""
def train(epoch, train_loader, train_data, batch_size, model):
    train_loss = 0
    epoch_loss = np.zeros(int(len (train_data) / batch_size ))
    clip, learning_rate, seed, print_every, save_every  = 10, 1e-3 , 100, 10, 10
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    for batch_idx, (data) in enumerate(train_loader):
        
        data = Variable(data)
        #forward + backward + optimize
        optimizer.zero_grad()
        re_loss,_,_ = model(data)
        epoch_loss [batch_idx] = re_loss
        loss = re_loss
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        #printing
        if batch_idx % print_every == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)] \t Reconstruction Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                re_loss.data / batch_size))

            

        train_loss += loss.data
    print('====> Epoch: {} Average loss: {:.4f}'.format(
        epoch, train_loss / len(train_loader.dataset)))
    return epoch_loss, model
    
def test(epoch, test_loader, test_data, model):
    """uses test data to evaluate 
    likelihood of the model"""
    mean_re_loss = 0
    epoch_loss = np.zeros(len(test_data))
    for i, (data) in enumerate(test_loader):                                           
        data = Variable(data.reshape(1,-1))
        re_loss, _,_ = model(data)
        epoch_loss [i] = re_loss
        mean_re_loss += re_loss.data

    mean_re_loss /= len(test_loader.dataset)

    print('====> Test set loss: Reconstruction Loss = {:.4f} '.format(
        mean_re_loss))
    return epoch_loss

# %% [markdown]
# ## Perform Dimensionality Reduction

# %%
""" This is the method that implements the dimensionality reduction based on Autoencoders """
def perform_dimensionality_reduction (hyper_paras, path):
    seed = 100
    # Change the 0.3 to 0.6 and 0.9 for 60 % and 90 % dimensionality reduction
    z_dim = int(50-0.3 * 50) # 30 % dimensionality reduction
    n_epochs, batch_size = hyper_paras
    train_data, test_data = load_rescale_data_sets(path)
    x_dim = train_data.shape[1]
    
    h1_dim = int (x_dim - (1/5) * (x_dim - z_dim))
    h2_dim = int (x_dim - (2/5) * (x_dim - z_dim))
    h3_dim = int (x_dim - (3/5) * (x_dim - z_dim))
    h4_dim = int (x_dim - (4/5) * (x_dim - z_dim))
    
    print (x_dim, h1_dim, h2_dim, h3_dim,h4_dim,z_dim)
    
    torch.manual_seed(seed)
    train_loader = torch.utils.data.DataLoader ( dataset = train_data.values ,  batch_size = batch_size , shuffle= True)
    test_loader = torch.utils.data.DataLoader (  dataset = test_data.values , shuffle= True)
    train_error = np.zeros([n_epochs , int(train_data.shape[0] / batch_size ) ])
    test_error = np.zeros([n_epochs , test_data.shape[0]])  
    for epoch in range(1, n_epochs + 1):
        #training + testing
        if (epoch==1): ## only for the first time, take the default model, all the next times in iteration, keep improving it
            model = AE(x_dim, z_dim)
            
        tr = train(epoch, train_loader, train_data, batch_size, model)
        train_error [epoch-1 , :] = tr [0]
        model = tr[1]
        te = test(epoch, test_loader, test_data, model)
        test_error [epoch-1 , :] = te [0]
            
    train_lat = [ model (Variable(torch.tensor(train_data.iloc[idx,:].values)).reshape(1,-1))[1] for idx in range(len(train_data)) ]
    test_lat = [ model (Variable(torch.tensor(test_data.iloc[idx,:].values)).reshape(1,-1))[1] for idx in range(len(test_data)) ]
    train_lat = pd.DataFrame(torch.cat(train_lat).cpu().detach().numpy())
    test_lat = pd.DataFrame(torch.cat(test_lat).cpu().detach().numpy())
    cols = []
    for i in range(train_lat.shape[1]):
        cols.append(str('Z'+str(i+1)))
    train_lat.columns = cols
    test_lat.columns = cols
    train_lat.to_csv('AEs_ELN_50D_30%_latent_training.csv') # Change the path here depending upon dimensionality and reduction
    test_lat.to_csv('AEs_ELN_50D_30%_latent_test.csv') # Same here
    return train_error, test_error

# %% [markdown]
# ## End Dimensionality Reduction Related Code

# %% [markdown]
# ## Load New Reduced Data Sets for all Test Cases

# %%
def load_f2(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets\\test_2_200Samples.csv')).iloc[:,-1] 
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f3(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets\\test_3_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f7(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets\\test_7_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f9(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets\\test_9_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f10(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets\\test_10_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f13(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets\\test_13_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f15(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets\\test_15_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f16(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets\\test_16_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f20(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets\\test_20_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f24(path,path_latent_train,path_latent_test):
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets\\test_24_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

# %% [markdown]
# ##  Start Polynomial Surrogate Modelling Code

# %%
''' Elastic Net Regression '''
def elastic_net(train_data,test_data,hyper):
    alp, rat = hyper
    scaler =  MinMaxScaler().fit(np.r_[train_data.iloc[:,:-1].values])
    regr = ElasticNet(alpha= np.power(10,alp) ,random_state=0 , l1_ratio=rat, fit_intercept =True, max_iter=3000,selection='random').fit(scaler.transform ( np.array(train_data.iloc[:,:-1])) ,  np.array(train_data.iloc[:,-1]))
    pred = regr.predict(scaler.transform(test_data))
    return regr,pred

""" Generating Polynomial Features i.e., Function Basis """
def quadratic_polynomial (df):
    return pd.DataFrame(PolynomialFeatures(degree=2).fit_transform(df))

""" Quadratic Regression with Elastic Net Penalty"""
def polynomial(tr, te,hyper):
    f_original = tr['Y']
    temp1 = quadratic_polynomial (tr.iloc[:,:-1])
    temp2 = quadratic_polynomial (te.iloc[:,:-1])
    temp1 ['Y'] = f_original
    model_eln , pred_eln = elastic_net(temp1,temp2,hyper)
    return model_eln , pred_eln


""" Normalized Mean Absolute Error % """
def rmae(true, pred):
    return np.mean((abs(true-pred) / abs(true)) * 100)

""" This method implements and evaluates the Polynomial Surrogate Model with RMAE """
def surrogate_model(train_data,test_data,hyper,true):
    model_eln , pred_eln = polynomial (train_data,test_data,hyper)
    return rmae(true,pred_eln)

""" Implements all the surrogate models, i.e., for all test function, and returns the median of RMAE errors,
This median is used as the primary metric for Hyper-Parameters Optimization """
def perform_surrogate_modeling(paths, path_latent_train,path_latent_test,hyper):
    train_2, test_2, true_2 = load_f2(paths[0],path_latent_train,path_latent_test)
    rmae_2 = surrogate_model(train_2, test_2,hyper, true_2)
    
    train_3, test_3, true_3 = load_f3(paths[1],path_latent_train,path_latent_test)
    rmae_3 = surrogate_model(train_3, test_3,hyper, true_3)
    
    train_7, test_7, true_7 = load_f7(paths[2],path_latent_train,path_latent_test)
    rmae_7 = surrogate_model(train_7, test_7,hyper, true_7)
    
    train_9, test_9, true_9 = load_f9(paths[3],path_latent_train,path_latent_test)
    rmae_9 = surrogate_model(train_9, test_9,hyper, true_9)
    
    train_10, test_10, true_10 = load_f10(paths[4],path_latent_train,path_latent_test)
    rmae_10 = surrogate_model(train_10, test_10,hyper, true_10)
    
    train_13, test_13, true_13 = load_f13(paths[5],path_latent_train,path_latent_test)
    rmae_13 = surrogate_model(train_13, test_13,hyper, true_13)
    
    train_15, test_15, true_15 = load_f15(paths[6],path_latent_train,path_latent_test)
    rmae_15 = surrogate_model(train_15, test_15,hyper, true_15)
    
    train_16, test_16, true_16 = load_f16(paths[7],path_latent_train,path_latent_test)
    rmae_16 = surrogate_model(train_16, test_16,hyper, true_16)
    
    train_20, test_20, true_20 = load_f20(paths[8],path_latent_train,path_latent_test)
    rmae_20 = surrogate_model(train_20, test_20,hyper, true_20)
    
    train_24, test_24, true_24 = load_f24(paths[9],path_latent_train,path_latent_test)
    rmae_24 = surrogate_model(train_24, test_24,hyper, true_24)
    
    accuracy = [rmae_2,rmae_3,rmae_7,rmae_9,rmae_10,rmae_13,rmae_15,rmae_16,rmae_20,rmae_24]
    return accuracy

""" This is the function used for Hyper_Parameters_Optimization for both dimensionality reduction and surrogate modelling """
def hyper_parameters_optimization(hyper_dim,path_latent_train,path_latent_test,hyper):
    print ('Start Dimensionality Reduction:::')
    _ , _ = perform_dimensionality_reduction (hyper_dim, paths[0])
    print ('End Dimensionality Reduction:::')
    accuracy = perform_surrogate_modeling (paths,path_latent_train,path_latent_test,hyper)
    return accuracy

# %% [markdown]
# ## End Surrogate Modelling Code

# %% [markdown]
# ## Set Paths

# %%
# Change the Paths here depending upon the dimensionality {50D=1000,100D=2000,200D=4000} 
path_2 = "Data Generation\\50 D\\Training_Data_Sets\\train_2_1000Samples.csv"
path_3 = "Data Generation\\50 D\\Training_Data_Sets\\train_3_1000Samples.csv"
path_7 = "Data Generation\\50 D\\Training_Data_Sets\\train_7_1000Samples.csv"
path_9 = "Data Generation\\50 D\\Training_Data_Sets\\train_9_1000Samples.csv"
path_10 = "Data Generation\\50 D\\Training_Data_Sets\\train_10_1000Samples.csv"
path_13 = "Data Generation\\50 D\\Training_Data_Sets\\train_13_1000Samples.csv"
path_15 = "Data Generation\\50 D\\Training_Data_Sets\\train_15_1000Samples.csv"
path_16 = "Data Generation\\50 D\\Training_Data_Sets\\train_16_1000Samples.csv"
path_20 = "Data Generation\\50 D\\Training_Data_Sets\\train_201000Samples.csv"
path_24 = "Data Generation\\50 D\\Training_Data_Sets\\train_241000Samples.csv"
# Change the Paths here depending upon the dimensionality {50D,100D,200D} and % of reduction{30,60,90} 
path_latent_train = "AEs_ELN_50D_30%_latent_training.csv"
path_latent_test = "AEs_ELN_50D_30%_latent_test.csv"
paths = [path_2,path_3,path_7,path_9,path_10,path_13,path_15,path_16,path_20,path_24]

# %% [markdown]
# ## Run the Code

# %%
hyper_dim = [40,10]
hyper_surrogate = [-1.6460835015125062, 0.9981172056554478]
accuracy = hyper_parameters_optimization(hyper_dim,path_latent_train,path_latent_test,hyper_surrogate)
print ('The Median accuracy:::'+str(np.median(accuracy)))
# Out:
# Start Dimensionality Reduction:::
# 50 47 44 41 38 35
# Train Epoch: 1 [0/1000 (0%)] 	 Reconstruction Loss: 0.033593
# Train Epoch: 1 [100/1000 (10%)] 	 Reconstruction Loss: 0.023517
# Train Epoch: 1 [200/1000 (20%)] 	 Reconstruction Loss: 0.011204
# Train Epoch: 1 [300/1000 (30%)] 	 Reconstruction Loss: 0.009051
# Train Epoch: 1 [400/1000 (40%)] 	 Reconstruction Loss: 0.008645
# Train Epoch: 1 [500/1000 (50%)] 	 Reconstruction Loss: 0.008355
# Train Epoch: 1 [600/1000 (60%)] 	 Reconstruction Loss: 0.008864
# Train Epoch: 1 [700/1000 (70%)] 	 Reconstruction Loss: 0.007933
# Train Epoch: 1 [800/1000 (80%)] 	 Reconstruction Loss: 0.008626
# Train Epoch: 1 [900/1000 (90%)] 	 Reconstruction Loss: 0.008854
# ====> Epoch: 1 Average loss: 0.0119
# ====> Test set loss: Reconstruction Loss = 0.0852
# Train Epoch: 2 [0/1000 (0%)] 	 Reconstruction Loss: 0.008861
# Train Epoch: 2 [100/1000 (10%)] 	 Reconstruction Loss: 0.008965
# Train Epoch: 2 [200/1000 (20%)] 	 Reconstruction Loss: 0.008718
# Train Epoch: 2 [300/1000 (30%)] 	 Reconstruction Loss: 0.008507
# Train Epoch: 2 [400/1000 (40%)] 	 Reconstruction Loss: 0.008332
# Train Epoch: 2 [500/1000 (50%)] 	 Reconstruction Loss: 0.008626
# Train Epoch: 2 [600/1000 (60%)] 	 Reconstruction Loss: 0.008771
# Train Epoch: 2 [700/1000 (70%)] 	 Reconstruction Loss: 0.008370
# Train Epoch: 2 [800/1000 (80%)] 	 Reconstruction Loss: 0.008517
# Train Epoch: 2 [900/1000 (90%)] 	 Reconstruction Loss: 0.008681
# ====> Epoch: 2 Average loss: 0.0085
# ====> Test set loss: Reconstruction Loss = 0.0849
# Train Epoch: 3 [0/1000 (0%)] 	 Reconstruction Loss: 0.008613
# Train Epoch: 3 [100/1000 (10%)] 	 Reconstruction Loss: 0.008424
# Train Epoch: 3 [200/1000 (20%)] 	 Reconstruction Loss: 0.008619
# Train Epoch: 3 [300/1000 (30%)] 	 Reconstruction Loss: 0.007929
# Train Epoch: 3 [400/1000 (40%)] 	 Reconstruction Loss: 0.007915
# Train Epoch: 3 [500/1000 (50%)] 	 Reconstruction Loss: 0.008043
# Train Epoch: 3 [600/1000 (60%)] 	 Reconstruction Loss: 0.008031
# Train Epoch: 3 [700/1000 (70%)] 	 Reconstruction Loss: 0.007739
# Train Epoch: 3 [800/1000 (80%)] 	 Reconstruction Loss: 0.007417
# Train Epoch: 3 [900/1000 (90%)] 	 Reconstruction Loss: 0.008262
# ====> Epoch: 3 Average loss: 0.0083
# ====> Test set loss: Reconstruction Loss = 0.0803
# Train Epoch: 4 [0/1000 (0%)] 	 Reconstruction Loss: 0.007858
# Train Epoch: 4 [100/1000 (10%)] 	 Reconstruction Loss: 0.008244
# Train Epoch: 4 [200/1000 (20%)] 	 Reconstruction Loss: 0.007915
# Train Epoch: 4 [300/1000 (30%)] 	 Reconstruction Loss: 0.007069
# Train Epoch: 4 [400/1000 (40%)] 	 Reconstruction Loss: 0.007180
# Train Epoch: 4 [500/1000 (50%)] 	 Reconstruction Loss: 0.008058
# Train Epoch: 4 [600/1000 (60%)] 	 Reconstruction Loss: 0.007940
# Train Epoch: 4 [700/1000 (70%)] 	 Reconstruction Loss: 0.008434
# Train Epoch: 4 [800/1000 (80%)] 	 Reconstruction Loss: 0.008070
# Train Epoch: 4 [900/1000 (90%)] 	 Reconstruction Loss: 0.007545
# ====> Epoch: 4 Average loss: 0.0079
# ====> Test set loss: Reconstruction Loss = 0.0779
# Train Epoch: 5 [0/1000 (0%)] 	 Reconstruction Loss: 0.008507
# Train Epoch: 5 [100/1000 (10%)] 	 Reconstruction Loss: 0.007710
# Train Epoch: 5 [200/1000 (20%)] 	 Reconstruction Loss: 0.007501
# Train Epoch: 5 [300/1000 (30%)] 	 Reconstruction Loss: 0.008053
# Train Epoch: 5 [400/1000 (40%)] 	 Reconstruction Loss: 0.007618
# Train Epoch: 5 [500/1000 (50%)] 	 Reconstruction Loss: 0.007663
# Train Epoch: 5 [600/1000 (60%)] 	 Reconstruction Loss: 0.007550
# Train Epoch: 5 [700/1000 (70%)] 	 Reconstruction Loss: 0.007341
# Train Epoch: 5 [800/1000 (80%)] 	 Reconstruction Loss: 0.007320
# Train Epoch: 5 [900/1000 (90%)] 	 Reconstruction Loss: 0.007621
# ====> Epoch: 5 Average loss: 0.0077
# ====> Test set loss: Reconstruction Loss = 0.0760
# Train Epoch: 6 [0/1000 (0%)] 	 Reconstruction Loss: 0.007591
# Train Epoch: 6 [100/1000 (10%)] 	 Reconstruction Loss: 0.008231
# Train Epoch: 6 [200/1000 (20%)] 	 Reconstruction Loss: 0.007480
# Train Epoch: 6 [300/1000 (30%)] 	 Reconstruction Loss: 0.007450
# Train Epoch: 6 [400/1000 (40%)] 	 Reconstruction Loss: 0.007518
# Train Epoch: 6 [500/1000 (50%)] 	 Reconstruction Loss: 0.007628
# Train Epoch: 6 [600/1000 (60%)] 	 Reconstruction Loss: 0.007464
# Train Epoch: 6 [700/1000 (70%)] 	 Reconstruction Loss: 0.007889
# Train Epoch: 6 [800/1000 (80%)] 	 Reconstruction Loss: 0.006943
# Train Epoch: 6 [900/1000 (90%)] 	 Reconstruction Loss: 0.007338
# ====> Epoch: 6 Average loss: 0.0075
# ====> Test set loss: Reconstruction Loss = 0.0749
# Train Epoch: 7 [0/1000 (0%)] 	 Reconstruction Loss: 0.006885
# Train Epoch: 7 [100/1000 (10%)] 	 Reconstruction Loss: 0.006824
# Train Epoch: 7 [200/1000 (20%)] 	 Reconstruction Loss: 0.007131
# Train Epoch: 7 [300/1000 (30%)] 	 Reconstruction Loss: 0.007582
# Train Epoch: 7 [400/1000 (40%)] 	 Reconstruction Loss: 0.007158
# Train Epoch: 7 [500/1000 (50%)] 	 Reconstruction Loss: 0.007116
# Train Epoch: 7 [600/1000 (60%)] 	 Reconstruction Loss: 0.007985
# Train Epoch: 7 [700/1000 (70%)] 	 Reconstruction Loss: 0.007743
# Train Epoch: 7 [800/1000 (80%)] 	 Reconstruction Loss: 0.007090
# Train Epoch: 7 [900/1000 (90%)] 	 Reconstruction Loss: 0.007309
# ====> Epoch: 7 Average loss: 0.0073
# ====> Test set loss: Reconstruction Loss = 0.0732
# Train Epoch: 8 [0/1000 (0%)] 	 Reconstruction Loss: 0.007163
# Train Epoch: 8 [100/1000 (10%)] 	 Reconstruction Loss: 0.007492
# Train Epoch: 8 [200/1000 (20%)] 	 Reconstruction Loss: 0.006731
# Train Epoch: 8 [300/1000 (30%)] 	 Reconstruction Loss: 0.007091
# Train Epoch: 8 [400/1000 (40%)] 	 Reconstruction Loss: 0.007678
# Train Epoch: 8 [500/1000 (50%)] 	 Reconstruction Loss: 0.007093
# Train Epoch: 8 [600/1000 (60%)] 	 Reconstruction Loss: 0.007331
# Train Epoch: 8 [700/1000 (70%)] 	 Reconstruction Loss: 0.007308
# Train Epoch: 8 [800/1000 (80%)] 	 Reconstruction Loss: 0.007166
# Train Epoch: 8 [900/1000 (90%)] 	 Reconstruction Loss: 0.007180
# ====> Epoch: 8 Average loss: 0.0071
# ====> Test set loss: Reconstruction Loss = 0.0729
# Train Epoch: 9 [0/1000 (0%)] 	 Reconstruction Loss: 0.006818
# Train Epoch: 9 [100/1000 (10%)] 	 Reconstruction Loss: 0.006465
# Train Epoch: 9 [200/1000 (20%)] 	 Reconstruction Loss: 0.007193
# Train Epoch: 9 [300/1000 (30%)] 	 Reconstruction Loss: 0.007198
# Train Epoch: 9 [400/1000 (40%)] 	 Reconstruction Loss: 0.006832
# Train Epoch: 9 [500/1000 (50%)] 	 Reconstruction Loss: 0.007065
# Train Epoch: 9 [600/1000 (60%)] 	 Reconstruction Loss: 0.006763
# Train Epoch: 9 [700/1000 (70%)] 	 Reconstruction Loss: 0.007100
# Train Epoch: 9 [800/1000 (80%)] 	 Reconstruction Loss: 0.007175
# Train Epoch: 9 [900/1000 (90%)] 	 Reconstruction Loss: 0.006249
# ====> Epoch: 9 Average loss: 0.0071
# ====> Test set loss: Reconstruction Loss = 0.0717
# Train Epoch: 10 [0/1000 (0%)] 	 Reconstruction Loss: 0.006991
# Train Epoch: 10 [100/1000 (10%)] 	 Reconstruction Loss: 0.007103
# Train Epoch: 10 [200/1000 (20%)] 	 Reconstruction Loss: 0.006752
# Train Epoch: 10 [300/1000 (30%)] 	 Reconstruction Loss: 0.007143
# Train Epoch: 10 [400/1000 (40%)] 	 Reconstruction Loss: 0.006705
# Train Epoch: 10 [500/1000 (50%)] 	 Reconstruction Loss: 0.007113
# Train Epoch: 10 [600/1000 (60%)] 	 Reconstruction Loss: 0.006769
# Train Epoch: 10 [700/1000 (70%)] 	 Reconstruction Loss: 0.007112
# Train Epoch: 10 [800/1000 (80%)] 	 Reconstruction Loss: 0.006879
# Train Epoch: 10 [900/1000 (90%)] 	 Reconstruction Loss: 0.007080
# ====> Epoch: 10 Average loss: 0.0069
# ====> Test set loss: Reconstruction Loss = 0.0710
# Train Epoch: 11 [0/1000 (0%)] 	 Reconstruction Loss: 0.006910
# Train Epoch: 11 [100/1000 (10%)] 	 Reconstruction Loss: 0.006170
# Train Epoch: 11 [200/1000 (20%)] 	 Reconstruction Loss: 0.007161
# Train Epoch: 11 [300/1000 (30%)] 	 Reconstruction Loss: 0.007185
# Train Epoch: 11 [400/1000 (40%)] 	 Reconstruction Loss: 0.006831
# Train Epoch: 11 [500/1000 (50%)] 	 Reconstruction Loss: 0.006801
# Train Epoch: 11 [600/1000 (60%)] 	 Reconstruction Loss: 0.007131
# Train Epoch: 11 [700/1000 (70%)] 	 Reconstruction Loss: 0.006910
# Train Epoch: 11 [800/1000 (80%)] 	 Reconstruction Loss: 0.006373
# Train Epoch: 11 [900/1000 (90%)] 	 Reconstruction Loss: 0.006920
# ====> Epoch: 11 Average loss: 0.0069
# ====> Test set loss: Reconstruction Loss = 0.0701
# Train Epoch: 12 [0/1000 (0%)] 	 Reconstruction Loss: 0.006771
# Train Epoch: 12 [100/1000 (10%)] 	 Reconstruction Loss: 0.006809
# Train Epoch: 12 [200/1000 (20%)] 	 Reconstruction Loss: 0.006907
# Train Epoch: 12 [300/1000 (30%)] 	 Reconstruction Loss: 0.006467
# Train Epoch: 12 [400/1000 (40%)] 	 Reconstruction Loss: 0.007055
# Train Epoch: 12 [500/1000 (50%)] 	 Reconstruction Loss: 0.006325
# Train Epoch: 12 [600/1000 (60%)] 	 Reconstruction Loss: 0.006268
# Train Epoch: 12 [700/1000 (70%)] 	 Reconstruction Loss: 0.006812
# Train Epoch: 12 [800/1000 (80%)] 	 Reconstruction Loss: 0.006759
# Train Epoch: 12 [900/1000 (90%)] 	 Reconstruction Loss: 0.005748
# ====> Epoch: 12 Average loss: 0.0067
# ====> Test set loss: Reconstruction Loss = 0.0685
# Train Epoch: 13 [0/1000 (0%)] 	 Reconstruction Loss: 0.005694
# Train Epoch: 13 [100/1000 (10%)] 	 Reconstruction Loss: 0.006859
# Train Epoch: 13 [200/1000 (20%)] 	 Reconstruction Loss: 0.006789
# Train Epoch: 13 [300/1000 (30%)] 	 Reconstruction Loss: 0.006576
# Train Epoch: 13 [400/1000 (40%)] 	 Reconstruction Loss: 0.006398
# Train Epoch: 13 [500/1000 (50%)] 	 Reconstruction Loss: 0.006080
# Train Epoch: 13 [600/1000 (60%)] 	 Reconstruction Loss: 0.006713
# Train Epoch: 13 [700/1000 (70%)] 	 Reconstruction Loss: 0.006220
# Train Epoch: 13 [800/1000 (80%)] 	 Reconstruction Loss: 0.006700
# Train Epoch: 13 [900/1000 (90%)] 	 Reconstruction Loss: 0.006593
# ====> Epoch: 13 Average loss: 0.0065
# ====> Test set loss: Reconstruction Loss = 0.0678
# Train Epoch: 14 [0/1000 (0%)] 	 Reconstruction Loss: 0.005768
# Train Epoch: 14 [100/1000 (10%)] 	 Reconstruction Loss: 0.006491
# Train Epoch: 14 [200/1000 (20%)] 	 Reconstruction Loss: 0.006520
# Train Epoch: 14 [300/1000 (30%)] 	 Reconstruction Loss: 0.006736
# Train Epoch: 14 [400/1000 (40%)] 	 Reconstruction Loss: 0.006417
# Train Epoch: 14 [500/1000 (50%)] 	 Reconstruction Loss: 0.006346
# Train Epoch: 14 [600/1000 (60%)] 	 Reconstruction Loss: 0.006321
# Train Epoch: 14 [700/1000 (70%)] 	 Reconstruction Loss: 0.006428
# Train Epoch: 14 [800/1000 (80%)] 	 Reconstruction Loss: 0.006572
# Train Epoch: 14 [900/1000 (90%)] 	 Reconstruction Loss: 0.006153
# ====> Epoch: 14 Average loss: 0.0065
# ====> Test set loss: Reconstruction Loss = 0.0678
# Train Epoch: 15 [0/1000 (0%)] 	 Reconstruction Loss: 0.006060
# Train Epoch: 15 [100/1000 (10%)] 	 Reconstruction Loss: 0.006384
# Train Epoch: 15 [200/1000 (20%)] 	 Reconstruction Loss: 0.006596
# Train Epoch: 15 [300/1000 (30%)] 	 Reconstruction Loss: 0.006252
# Train Epoch: 15 [400/1000 (40%)] 	 Reconstruction Loss: 0.006789
# Train Epoch: 15 [500/1000 (50%)] 	 Reconstruction Loss: 0.006529
# Train Epoch: 15 [600/1000 (60%)] 	 Reconstruction Loss: 0.006021
# Train Epoch: 15 [700/1000 (70%)] 	 Reconstruction Loss: 0.006388
# Train Epoch: 15 [800/1000 (80%)] 	 Reconstruction Loss: 0.006281
# Train Epoch: 15 [900/1000 (90%)] 	 Reconstruction Loss: 0.006882
# ====> Epoch: 15 Average loss: 0.0064
# ====> Test set loss: Reconstruction Loss = 0.0671
# Train Epoch: 16 [0/1000 (0%)] 	 Reconstruction Loss: 0.006268
# Train Epoch: 16 [100/1000 (10%)] 	 Reconstruction Loss: 0.006710
# Train Epoch: 16 [200/1000 (20%)] 	 Reconstruction Loss: 0.006580
# Train Epoch: 16 [300/1000 (30%)] 	 Reconstruction Loss: 0.006289
# Train Epoch: 16 [400/1000 (40%)] 	 Reconstruction Loss: 0.005462
# Train Epoch: 16 [500/1000 (50%)] 	 Reconstruction Loss: 0.006438
# Train Epoch: 16 [600/1000 (60%)] 	 Reconstruction Loss: 0.006250
# Train Epoch: 16 [700/1000 (70%)] 	 Reconstruction Loss: 0.006101
# Train Epoch: 16 [800/1000 (80%)] 	 Reconstruction Loss: 0.006613
# Train Epoch: 16 [900/1000 (90%)] 	 Reconstruction Loss: 0.006649
# ====> Epoch: 16 Average loss: 0.0063
# ====> Test set loss: Reconstruction Loss = 0.0662
# Train Epoch: 17 [0/1000 (0%)] 	 Reconstruction Loss: 0.006196
# Train Epoch: 17 [100/1000 (10%)] 	 Reconstruction Loss: 0.006451
# Train Epoch: 17 [200/1000 (20%)] 	 Reconstruction Loss: 0.006551
# Train Epoch: 17 [300/1000 (30%)] 	 Reconstruction Loss: 0.005807
# Train Epoch: 17 [400/1000 (40%)] 	 Reconstruction Loss: 0.006330
# Train Epoch: 17 [500/1000 (50%)] 	 Reconstruction Loss: 0.005761
# Train Epoch: 17 [600/1000 (60%)] 	 Reconstruction Loss: 0.005662
# Train Epoch: 17 [700/1000 (70%)] 	 Reconstruction Loss: 0.005557
# Train Epoch: 17 [800/1000 (80%)] 	 Reconstruction Loss: 0.005839
# Train Epoch: 17 [900/1000 (90%)] 	 Reconstruction Loss: 0.006146
# ====> Epoch: 17 Average loss: 0.0062
# ====> Test set loss: Reconstruction Loss = 0.0651
# Train Epoch: 18 [0/1000 (0%)] 	 Reconstruction Loss: 0.005880
# Train Epoch: 18 [100/1000 (10%)] 	 Reconstruction Loss: 0.006101
# Train Epoch: 18 [200/1000 (20%)] 	 Reconstruction Loss: 0.006371
# Train Epoch: 18 [300/1000 (30%)] 	 Reconstruction Loss: 0.005869
# Train Epoch: 18 [400/1000 (40%)] 	 Reconstruction Loss: 0.006194
# Train Epoch: 18 [500/1000 (50%)] 	 Reconstruction Loss: 0.005688
# Train Epoch: 18 [600/1000 (60%)] 	 Reconstruction Loss: 0.006501
# Train Epoch: 18 [700/1000 (70%)] 	 Reconstruction Loss: 0.006261
# Train Epoch: 18 [800/1000 (80%)] 	 Reconstruction Loss: 0.006477
# Train Epoch: 18 [900/1000 (90%)] 	 Reconstruction Loss: 0.006393
# ====> Epoch: 18 Average loss: 0.0061
# ====> Test set loss: Reconstruction Loss = 0.0646
# Train Epoch: 19 [0/1000 (0%)] 	 Reconstruction Loss: 0.006070
# Train Epoch: 19 [100/1000 (10%)] 	 Reconstruction Loss: 0.006153
# Train Epoch: 19 [200/1000 (20%)] 	 Reconstruction Loss: 0.005965
# Train Epoch: 19 [300/1000 (30%)] 	 Reconstruction Loss: 0.006403
# Train Epoch: 19 [400/1000 (40%)] 	 Reconstruction Loss: 0.005666
# Train Epoch: 19 [500/1000 (50%)] 	 Reconstruction Loss: 0.006208
# Train Epoch: 19 [600/1000 (60%)] 	 Reconstruction Loss: 0.006186
# Train Epoch: 19 [700/1000 (70%)] 	 Reconstruction Loss: 0.005861
# Train Epoch: 19 [800/1000 (80%)] 	 Reconstruction Loss: 0.006195
# Train Epoch: 19 [900/1000 (90%)] 	 Reconstruction Loss: 0.005566
# ====> Epoch: 19 Average loss: 0.0060
# ====> Test set loss: Reconstruction Loss = 0.0647
# Train Epoch: 20 [0/1000 (0%)] 	 Reconstruction Loss: 0.006147
# Train Epoch: 20 [100/1000 (10%)] 	 Reconstruction Loss: 0.005810
# Train Epoch: 20 [200/1000 (20%)] 	 Reconstruction Loss: 0.005813
# Train Epoch: 20 [300/1000 (30%)] 	 Reconstruction Loss: 0.006095
# Train Epoch: 20 [400/1000 (40%)] 	 Reconstruction Loss: 0.005671
# Train Epoch: 20 [500/1000 (50%)] 	 Reconstruction Loss: 0.006599
# Train Epoch: 20 [600/1000 (60%)] 	 Reconstruction Loss: 0.006322
# Train Epoch: 20 [700/1000 (70%)] 	 Reconstruction Loss: 0.006080
# Train Epoch: 20 [800/1000 (80%)] 	 Reconstruction Loss: 0.006044
# Train Epoch: 20 [900/1000 (90%)] 	 Reconstruction Loss: 0.005981
# ====> Epoch: 20 Average loss: 0.0060
# ====> Test set loss: Reconstruction Loss = 0.0648
# Train Epoch: 21 [0/1000 (0%)] 	 Reconstruction Loss: 0.005489
# Train Epoch: 21 [100/1000 (10%)] 	 Reconstruction Loss: 0.005811
# Train Epoch: 21 [200/1000 (20%)] 	 Reconstruction Loss: 0.005243
# Train Epoch: 21 [300/1000 (30%)] 	 Reconstruction Loss: 0.006229
# Train Epoch: 21 [400/1000 (40%)] 	 Reconstruction Loss: 0.006228
# Train Epoch: 21 [500/1000 (50%)] 	 Reconstruction Loss: 0.005786
# Train Epoch: 21 [600/1000 (60%)] 	 Reconstruction Loss: 0.006102
# Train Epoch: 21 [700/1000 (70%)] 	 Reconstruction Loss: 0.006725
# Train Epoch: 21 [800/1000 (80%)] 	 Reconstruction Loss: 0.006008
# Train Epoch: 21 [900/1000 (90%)] 	 Reconstruction Loss: 0.005829
# ====> Epoch: 21 Average loss: 0.0060
# ====> Test set loss: Reconstruction Loss = 0.0639
# Train Epoch: 22 [0/1000 (0%)] 	 Reconstruction Loss: 0.005638
# Train Epoch: 22 [100/1000 (10%)] 	 Reconstruction Loss: 0.006240
# Train Epoch: 22 [200/1000 (20%)] 	 Reconstruction Loss: 0.005871
# Train Epoch: 22 [300/1000 (30%)] 	 Reconstruction Loss: 0.005849
# Train Epoch: 22 [400/1000 (40%)] 	 Reconstruction Loss: 0.005761
# Train Epoch: 22 [500/1000 (50%)] 	 Reconstruction Loss: 0.006349
# Train Epoch: 22 [600/1000 (60%)] 	 Reconstruction Loss: 0.006165
# Train Epoch: 22 [700/1000 (70%)] 	 Reconstruction Loss: 0.005649
# Train Epoch: 22 [800/1000 (80%)] 	 Reconstruction Loss: 0.005390
# Train Epoch: 22 [900/1000 (90%)] 	 Reconstruction Loss: 0.005811
# ====> Epoch: 22 Average loss: 0.0059
# ====> Test set loss: Reconstruction Loss = 0.0634
# Train Epoch: 23 [0/1000 (0%)] 	 Reconstruction Loss: 0.005729
# Train Epoch: 23 [100/1000 (10%)] 	 Reconstruction Loss: 0.005475
# Train Epoch: 23 [200/1000 (20%)] 	 Reconstruction Loss: 0.006109
# Train Epoch: 23 [300/1000 (30%)] 	 Reconstruction Loss: 0.005687
# Train Epoch: 23 [400/1000 (40%)] 	 Reconstruction Loss: 0.005964
# Train Epoch: 23 [500/1000 (50%)] 	 Reconstruction Loss: 0.005943
# Train Epoch: 23 [600/1000 (60%)] 	 Reconstruction Loss: 0.006122
# Train Epoch: 23 [700/1000 (70%)] 	 Reconstruction Loss: 0.005213
# Train Epoch: 23 [800/1000 (80%)] 	 Reconstruction Loss: 0.005263
# Train Epoch: 23 [900/1000 (90%)] 	 Reconstruction Loss: 0.005713
# ====> Epoch: 23 Average loss: 0.0058
# ====> Test set loss: Reconstruction Loss = 0.0633
# Train Epoch: 24 [0/1000 (0%)] 	 Reconstruction Loss: 0.005846
# Train Epoch: 24 [100/1000 (10%)] 	 Reconstruction Loss: 0.005834
# Train Epoch: 24 [200/1000 (20%)] 	 Reconstruction Loss: 0.005494
# Train Epoch: 24 [300/1000 (30%)] 	 Reconstruction Loss: 0.006038
# Train Epoch: 24 [400/1000 (40%)] 	 Reconstruction Loss: 0.006212
# Train Epoch: 24 [500/1000 (50%)] 	 Reconstruction Loss: 0.005228
# Train Epoch: 24 [600/1000 (60%)] 	 Reconstruction Loss: 0.005787
# Train Epoch: 24 [700/1000 (70%)] 	 Reconstruction Loss: 0.006122
# Train Epoch: 24 [800/1000 (80%)] 	 Reconstruction Loss: 0.006002
# Train Epoch: 24 [900/1000 (90%)] 	 Reconstruction Loss: 0.005229
# ====> Epoch: 24 Average loss: 0.0058
# ====> Test set loss: Reconstruction Loss = 0.0632
# Train Epoch: 25 [0/1000 (0%)] 	 Reconstruction Loss: 0.005740
# Train Epoch: 25 [100/1000 (10%)] 	 Reconstruction Loss: 0.005631
# Train Epoch: 25 [200/1000 (20%)] 	 Reconstruction Loss: 0.005503
# Train Epoch: 25 [300/1000 (30%)] 	 Reconstruction Loss: 0.005480
# Train Epoch: 25 [400/1000 (40%)] 	 Reconstruction Loss: 0.005424
# Train Epoch: 25 [500/1000 (50%)] 	 Reconstruction Loss: 0.005495
# Train Epoch: 25 [600/1000 (60%)] 	 Reconstruction Loss: 0.005654
# Train Epoch: 25 [700/1000 (70%)] 	 Reconstruction Loss: 0.005294
# Train Epoch: 25 [800/1000 (80%)] 	 Reconstruction Loss: 0.005802
# Train Epoch: 25 [900/1000 (90%)] 	 Reconstruction Loss: 0.005685
# ====> Epoch: 25 Average loss: 0.0058
# ====> Test set loss: Reconstruction Loss = 0.0632
# Train Epoch: 26 [0/1000 (0%)] 	 Reconstruction Loss: 0.005698
# Train Epoch: 26 [100/1000 (10%)] 	 Reconstruction Loss: 0.005386
# Train Epoch: 26 [200/1000 (20%)] 	 Reconstruction Loss: 0.005672
# Train Epoch: 26 [300/1000 (30%)] 	 Reconstruction Loss: 0.006134
# Train Epoch: 26 [400/1000 (40%)] 	 Reconstruction Loss: 0.005345
# Train Epoch: 26 [500/1000 (50%)] 	 Reconstruction Loss: 0.005902
# Train Epoch: 26 [600/1000 (60%)] 	 Reconstruction Loss: 0.005993
# Train Epoch: 26 [700/1000 (70%)] 	 Reconstruction Loss: 0.005719
# Train Epoch: 26 [800/1000 (80%)] 	 Reconstruction Loss: 0.005117
# Train Epoch: 26 [900/1000 (90%)] 	 Reconstruction Loss: 0.006345
# ====> Epoch: 26 Average loss: 0.0058
# ====> Test set loss: Reconstruction Loss = 0.0632
# Train Epoch: 27 [0/1000 (0%)] 	 Reconstruction Loss: 0.006315
# Train Epoch: 27 [100/1000 (10%)] 	 Reconstruction Loss: 0.006220
# Train Epoch: 27 [200/1000 (20%)] 	 Reconstruction Loss: 0.005267
# Train Epoch: 27 [300/1000 (30%)] 	 Reconstruction Loss: 0.006010
# Train Epoch: 27 [400/1000 (40%)] 	 Reconstruction Loss: 0.005663
# Train Epoch: 27 [500/1000 (50%)] 	 Reconstruction Loss: 0.005374
# Train Epoch: 27 [600/1000 (60%)] 	 Reconstruction Loss: 0.005728
# Train Epoch: 27 [700/1000 (70%)] 	 Reconstruction Loss: 0.005290
# Train Epoch: 27 [800/1000 (80%)] 	 Reconstruction Loss: 0.006033
# Train Epoch: 27 [900/1000 (90%)] 	 Reconstruction Loss: 0.005729
# ====> Epoch: 27 Average loss: 0.0058
# ====> Test set loss: Reconstruction Loss = 0.0630
# Train Epoch: 28 [0/1000 (0%)] 	 Reconstruction Loss: 0.005603
# Train Epoch: 28 [100/1000 (10%)] 	 Reconstruction Loss: 0.005315
# Train Epoch: 28 [200/1000 (20%)] 	 Reconstruction Loss: 0.005954
# Train Epoch: 28 [300/1000 (30%)] 	 Reconstruction Loss: 0.006449
# Train Epoch: 28 [400/1000 (40%)] 	 Reconstruction Loss: 0.005653
# Train Epoch: 28 [500/1000 (50%)] 	 Reconstruction Loss: 0.006468
# Train Epoch: 28 [600/1000 (60%)] 	 Reconstruction Loss: 0.005524
# Train Epoch: 28 [700/1000 (70%)] 	 Reconstruction Loss: 0.006171
# Train Epoch: 28 [800/1000 (80%)] 	 Reconstruction Loss: 0.005753
# Train Epoch: 28 [900/1000 (90%)] 	 Reconstruction Loss: 0.005849
# ====> Epoch: 28 Average loss: 0.0057
# ====> Test set loss: Reconstruction Loss = 0.0618
# Train Epoch: 29 [0/1000 (0%)] 	 Reconstruction Loss: 0.005495
# Train Epoch: 29 [100/1000 (10%)] 	 Reconstruction Loss: 0.005081
# Train Epoch: 29 [200/1000 (20%)] 	 Reconstruction Loss: 0.006127
# Train Epoch: 29 [300/1000 (30%)] 	 Reconstruction Loss: 0.005220
# Train Epoch: 29 [400/1000 (40%)] 	 Reconstruction Loss: 0.004929
# Train Epoch: 29 [500/1000 (50%)] 	 Reconstruction Loss: 0.005520
# Train Epoch: 29 [600/1000 (60%)] 	 Reconstruction Loss: 0.005420
# Train Epoch: 29 [700/1000 (70%)] 	 Reconstruction Loss: 0.005096
# Train Epoch: 29 [800/1000 (80%)] 	 Reconstruction Loss: 0.005536
# Train Epoch: 29 [900/1000 (90%)] 	 Reconstruction Loss: 0.005782
# ====> Epoch: 29 Average loss: 0.0056
# ====> Test set loss: Reconstruction Loss = 0.0616
# Train Epoch: 30 [0/1000 (0%)] 	 Reconstruction Loss: 0.004675
# Train Epoch: 30 [100/1000 (10%)] 	 Reconstruction Loss: 0.005727
# Train Epoch: 30 [200/1000 (20%)] 	 Reconstruction Loss: 0.006455
# Train Epoch: 30 [300/1000 (30%)] 	 Reconstruction Loss: 0.005824
# Train Epoch: 30 [400/1000 (40%)] 	 Reconstruction Loss: 0.005509
# Train Epoch: 30 [500/1000 (50%)] 	 Reconstruction Loss: 0.005915
# Train Epoch: 30 [600/1000 (60%)] 	 Reconstruction Loss: 0.005632
# Train Epoch: 30 [700/1000 (70%)] 	 Reconstruction Loss: 0.005575
# Train Epoch: 30 [800/1000 (80%)] 	 Reconstruction Loss: 0.005649
# Train Epoch: 30 [900/1000 (90%)] 	 Reconstruction Loss: 0.005006
# ====> Epoch: 30 Average loss: 0.0056
# ====> Test set loss: Reconstruction Loss = 0.0614
# Train Epoch: 31 [0/1000 (0%)] 	 Reconstruction Loss: 0.005863
# Train Epoch: 31 [100/1000 (10%)] 	 Reconstruction Loss: 0.005755
# Train Epoch: 31 [200/1000 (20%)] 	 Reconstruction Loss: 0.005450
# Train Epoch: 31 [300/1000 (30%)] 	 Reconstruction Loss: 0.006291
# Train Epoch: 31 [400/1000 (40%)] 	 Reconstruction Loss: 0.005030
# Train Epoch: 31 [500/1000 (50%)] 	 Reconstruction Loss: 0.005199
# Train Epoch: 31 [600/1000 (60%)] 	 Reconstruction Loss: 0.005546
# Train Epoch: 31 [700/1000 (70%)] 	 Reconstruction Loss: 0.005547
# Train Epoch: 31 [800/1000 (80%)] 	 Reconstruction Loss: 0.005738
# Train Epoch: 31 [900/1000 (90%)] 	 Reconstruction Loss: 0.005404
# ====> Epoch: 31 Average loss: 0.0056
# ====> Test set loss: Reconstruction Loss = 0.0614
# Train Epoch: 32 [0/1000 (0%)] 	 Reconstruction Loss: 0.006356
# Train Epoch: 32 [100/1000 (10%)] 	 Reconstruction Loss: 0.004971
# Train Epoch: 32 [200/1000 (20%)] 	 Reconstruction Loss: 0.005494
# Train Epoch: 32 [300/1000 (30%)] 	 Reconstruction Loss: 0.005735
# Train Epoch: 32 [400/1000 (40%)] 	 Reconstruction Loss: 0.005152
# Train Epoch: 32 [500/1000 (50%)] 	 Reconstruction Loss: 0.005731
# Train Epoch: 32 [600/1000 (60%)] 	 Reconstruction Loss: 0.005682
# Train Epoch: 32 [700/1000 (70%)] 	 Reconstruction Loss: 0.005813
# Train Epoch: 32 [800/1000 (80%)] 	 Reconstruction Loss: 0.005417
# Train Epoch: 32 [900/1000 (90%)] 	 Reconstruction Loss: 0.005406
# ====> Epoch: 32 Average loss: 0.0056
# ====> Test set loss: Reconstruction Loss = 0.0618
# Train Epoch: 33 [0/1000 (0%)] 	 Reconstruction Loss: 0.005076
# Train Epoch: 33 [100/1000 (10%)] 	 Reconstruction Loss: 0.005745
# Train Epoch: 33 [200/1000 (20%)] 	 Reconstruction Loss: 0.005321
# Train Epoch: 33 [300/1000 (30%)] 	 Reconstruction Loss: 0.005349
# Train Epoch: 33 [400/1000 (40%)] 	 Reconstruction Loss: 0.005180
# Train Epoch: 33 [500/1000 (50%)] 	 Reconstruction Loss: 0.005027
# Train Epoch: 33 [600/1000 (60%)] 	 Reconstruction Loss: 0.005888
# Train Epoch: 33 [700/1000 (70%)] 	 Reconstruction Loss: 0.005642
# Train Epoch: 33 [800/1000 (80%)] 	 Reconstruction Loss: 0.005387
# Train Epoch: 33 [900/1000 (90%)] 	 Reconstruction Loss: 0.006143
# ====> Epoch: 33 Average loss: 0.0056
# ====> Test set loss: Reconstruction Loss = 0.0614
# Train Epoch: 34 [0/1000 (0%)] 	 Reconstruction Loss: 0.004968
# Train Epoch: 34 [100/1000 (10%)] 	 Reconstruction Loss: 0.005841
# Train Epoch: 34 [200/1000 (20%)] 	 Reconstruction Loss: 0.005048
# Train Epoch: 34 [300/1000 (30%)] 	 Reconstruction Loss: 0.005010
# Train Epoch: 34 [400/1000 (40%)] 	 Reconstruction Loss: 0.005779
# Train Epoch: 34 [500/1000 (50%)] 	 Reconstruction Loss: 0.005250
# Train Epoch: 34 [600/1000 (60%)] 	 Reconstruction Loss: 0.005499
# Train Epoch: 34 [700/1000 (70%)] 	 Reconstruction Loss: 0.005626
# Train Epoch: 34 [800/1000 (80%)] 	 Reconstruction Loss: 0.006070
# Train Epoch: 34 [900/1000 (90%)] 	 Reconstruction Loss: 0.005407
# ====> Epoch: 34 Average loss: 0.0056
# ====> Test set loss: Reconstruction Loss = 0.0614
# Train Epoch: 35 [0/1000 (0%)] 	 Reconstruction Loss: 0.005184
# Train Epoch: 35 [100/1000 (10%)] 	 Reconstruction Loss: 0.005353
# Train Epoch: 35 [200/1000 (20%)] 	 Reconstruction Loss: 0.005684
# Train Epoch: 35 [300/1000 (30%)] 	 Reconstruction Loss: 0.005721
# Train Epoch: 35 [400/1000 (40%)] 	 Reconstruction Loss: 0.005868
# Train Epoch: 35 [500/1000 (50%)] 	 Reconstruction Loss: 0.005281
# Train Epoch: 35 [600/1000 (60%)] 	 Reconstruction Loss: 0.005307
# Train Epoch: 35 [700/1000 (70%)] 	 Reconstruction Loss: 0.004999
# Train Epoch: 35 [800/1000 (80%)] 	 Reconstruction Loss: 0.004894
# Train Epoch: 35 [900/1000 (90%)] 	 Reconstruction Loss: 0.005720
# ====> Epoch: 35 Average loss: 0.0055
# ====> Test set loss: Reconstruction Loss = 0.0612
# Train Epoch: 36 [0/1000 (0%)] 	 Reconstruction Loss: 0.005511
# Train Epoch: 36 [100/1000 (10%)] 	 Reconstruction Loss: 0.005364
# Train Epoch: 36 [200/1000 (20%)] 	 Reconstruction Loss: 0.005952
# Train Epoch: 36 [300/1000 (30%)] 	 Reconstruction Loss: 0.005911
# Train Epoch: 36 [400/1000 (40%)] 	 Reconstruction Loss: 0.005301
# Train Epoch: 36 [500/1000 (50%)] 	 Reconstruction Loss: 0.005168
# Train Epoch: 36 [600/1000 (60%)] 	 Reconstruction Loss: 0.005252
# Train Epoch: 36 [700/1000 (70%)] 	 Reconstruction Loss: 0.005499
# Train Epoch: 36 [800/1000 (80%)] 	 Reconstruction Loss: 0.006225
# Train Epoch: 36 [900/1000 (90%)] 	 Reconstruction Loss: 0.005248
# ====> Epoch: 36 Average loss: 0.0055
# ====> Test set loss: Reconstruction Loss = 0.0600
# Train Epoch: 37 [0/1000 (0%)] 	 Reconstruction Loss: 0.005779
# Train Epoch: 37 [100/1000 (10%)] 	 Reconstruction Loss: 0.005581
# Train Epoch: 37 [200/1000 (20%)] 	 Reconstruction Loss: 0.004892
# Train Epoch: 37 [300/1000 (30%)] 	 Reconstruction Loss: 0.004962
# Train Epoch: 37 [400/1000 (40%)] 	 Reconstruction Loss: 0.005626
# Train Epoch: 37 [500/1000 (50%)] 	 Reconstruction Loss: 0.005097
# Train Epoch: 37 [600/1000 (60%)] 	 Reconstruction Loss: 0.005782
# Train Epoch: 37 [700/1000 (70%)] 	 Reconstruction Loss: 0.005551
# Train Epoch: 37 [800/1000 (80%)] 	 Reconstruction Loss: 0.005318
# Train Epoch: 37 [900/1000 (90%)] 	 Reconstruction Loss: 0.005016
# ====> Epoch: 37 Average loss: 0.0054
# ====> Test set loss: Reconstruction Loss = 0.0596
# Train Epoch: 38 [0/1000 (0%)] 	 Reconstruction Loss: 0.005256
# Train Epoch: 38 [100/1000 (10%)] 	 Reconstruction Loss: 0.005547
# Train Epoch: 38 [200/1000 (20%)] 	 Reconstruction Loss: 0.005533
# Train Epoch: 38 [300/1000 (30%)] 	 Reconstruction Loss: 0.005698
# Train Epoch: 38 [400/1000 (40%)] 	 Reconstruction Loss: 0.005223
# Train Epoch: 38 [500/1000 (50%)] 	 Reconstruction Loss: 0.005226
# Train Epoch: 38 [600/1000 (60%)] 	 Reconstruction Loss: 0.005609
# Train Epoch: 38 [700/1000 (70%)] 	 Reconstruction Loss: 0.005143
# Train Epoch: 38 [800/1000 (80%)] 	 Reconstruction Loss: 0.005668
# Train Epoch: 38 [900/1000 (90%)] 	 Reconstruction Loss: 0.005828
# ====> Epoch: 38 Average loss: 0.0054
# ====> Test set loss: Reconstruction Loss = 0.0596
# Train Epoch: 39 [0/1000 (0%)] 	 Reconstruction Loss: 0.004970
# Train Epoch: 39 [100/1000 (10%)] 	 Reconstruction Loss: 0.005349
# Train Epoch: 39 [200/1000 (20%)] 	 Reconstruction Loss: 0.005663
# Train Epoch: 39 [300/1000 (30%)] 	 Reconstruction Loss: 0.005184
# Train Epoch: 39 [400/1000 (40%)] 	 Reconstruction Loss: 0.005191
# Train Epoch: 39 [500/1000 (50%)] 	 Reconstruction Loss: 0.004965
# Train Epoch: 39 [600/1000 (60%)] 	 Reconstruction Loss: 0.005337
# Train Epoch: 39 [700/1000 (70%)] 	 Reconstruction Loss: 0.005577
# Train Epoch: 39 [800/1000 (80%)] 	 Reconstruction Loss: 0.005963
# Train Epoch: 39 [900/1000 (90%)] 	 Reconstruction Loss: 0.005532
# ====> Epoch: 39 Average loss: 0.0054
# ====> Test set loss: Reconstruction Loss = 0.0595
# Train Epoch: 40 [0/1000 (0%)] 	 Reconstruction Loss: 0.005747
# Train Epoch: 40 [100/1000 (10%)] 	 Reconstruction Loss: 0.005152
# Train Epoch: 40 [200/1000 (20%)] 	 Reconstruction Loss: 0.005591
# Train Epoch: 40 [300/1000 (30%)] 	 Reconstruction Loss: 0.005115
# Train Epoch: 40 [400/1000 (40%)] 	 Reconstruction Loss: 0.005381
# Train Epoch: 40 [500/1000 (50%)] 	 Reconstruction Loss: 0.006140
# Train Epoch: 40 [600/1000 (60%)] 	 Reconstruction Loss: 0.005433
# Train Epoch: 40 [700/1000 (70%)] 	 Reconstruction Loss: 0.005065
# Train Epoch: 40 [800/1000 (80%)] 	 Reconstruction Loss: 0.005334
# Train Epoch: 40 [900/1000 (90%)] 	 Reconstruction Loss: 0.005917
# ====> Epoch: 40 Average loss: 0.0054
# ====> Test set loss: Reconstruction Loss = 0.0594
# End Dimensionality Reduction:::
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3756763220846936e+17, tolerance: 54476629894442.05
#   positive)
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11165648.13256216, tolerance: 644468.389133437
#   positive)
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35077660.979091644, tolerance: 908658.0649560124
#   positive)
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30915775469932.863, tolerance: 12637899670.801533
#   positive)
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0313567618950755e+17, tolerance: 38292438908020.56
#   positive)
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115513.12205906212, tolerance: 26105.62377898663
#   positive)
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81988533.999259, tolerance: 861285.2630627062
#   positive)
# C:\Users\sefi\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4200762604743.9604, tolerance: 2241307681.0635905
#   positive)
# The Median accuracy:::23.903432881932744

# %% [markdown]
# ## A Note on the Possible Values of the Hyper_Parameters

# %%
""" A): Hyper-Parameters for Dimensionality Reduction::::

    Autoencoders takes 2 hyper parameters: Number of epochs and batch size respectively, 
    both of which are discrete variables.
    
    number of epochs, (Discrete Variable), Possible Values: {10,30,30,...,100}
    batch size: (Discrete Variable): Possible Values: {5,10,20,25,50,100}, 

"""
""" B): Hyper-Parameters for Polynomials::::

    Polynomials takes 2 hyper parameters: alpha and l1_ratio. Notably, both are float values
    https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html for more details
    
    Alpha (Continuous Variable, Ranges between -2 and 2, e.g., 0.1234
    l1_ratio (Continuous Variable, Ranges between 0 and 1, e.g., 0.97645
    
"""
model = AE(50, 35)
array = np.zeros((10000,35))
for i in range(len(array)):
    array [i] = model(Variable(torch.tensor(np.zeros(50))))[1].cpu().detach().numpy()
array1 = np.zeros((10000,35))
for i in range(len(array)):
    array1 [i] = model(Variable(torch.tensor(np.ones(50))))[1].cpu().detach().numpy()
np.mean(abs(np.mean(array1, 0)-np.mean(array, 0)))/4
