# %%
import pyDOE
from scipy import stats
import pandas as pd
import numpy as np
from scipy.optimize import minimize
from scipy.optimize import Bounds
from collections import namedtuple
import cma
from sklearn.preprocessing import MinMaxScaler
import scipy.stats.distributions as dist
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C, RationalQuadratic
from sklearn.gaussian_process.kernels import DotProduct
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import PolynomialFeatures
import bbobbenchmarks as bn
import sklearn

# %% [markdown]
# ## Load New Reduced Data Sets for all Test Cases

# %%
def load_f2(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f2.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f2.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets/test_2_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f3(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f3.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f3.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets/test_3_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f7(path):
    #  Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f7.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f7.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    #  Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets/test_7_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f9(path):
    #  Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f9.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f9.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets/test_9_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f10(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f10.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f10.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets/test_10_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f13(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f13.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f13.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets/test_13_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f15(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f15.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f15.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets/test_15_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f16(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f16.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f16.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-43]+str('Test_Data_Sets/test_16_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f20(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f20.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f20.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets/test_20_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

def load_f24(path):
    # Change the Values below depending on dimensionality and % reduction
    path_latent_train = "PCA_Kriging_50D_30%_latent_training_f24.csv"
    path_latent_test =  "PCA_Kriging_50D_30%_latent_test_f24.csv"
    train_y = pd.read_csv(path).iloc[:,-1]
    # Change the Path Here depending upon the dimensionality {50D=200,100D=400,200D=800}
    test_y = pd.read_csv(path[:-42]+str('Test_Data_Sets/test_24_200Samples.csv')).iloc[:,-1]
    train = pd.read_csv(path_latent_train, index_col = 0)
    test = pd.read_csv(path_latent_test, index_col = 0)
    train ['Y'] = train_y
    test ['Y'] = test_y
    del train_y
    del test_y
    true = np.array(test['Y'])
    return train,test,true

# %% [markdown]
# ## Surrogate Models & Helper Functions

# %%
ValueRange = namedtuple('ValueRange', ['min', 'max'])

def determinerange(values):
    """Determine the range of values in each dimension"""
    return ValueRange(np.min(values, axis=0), np.max(values, axis=0))


def linearscaletransform(values, *, range_in=None, range_out=ValueRange(0, 1), scale_only=False):
    """Perform a scale transformation of `values`: [range_in] --> [range_out]"""

    if range_in is None:
        range_in = determinerange(values)
    elif not isinstance(range_in, ValueRange):
        range_in = ValueRange(*range_in)

    if not isinstance(range_out, ValueRange):
        range_out = ValueRange(*range_out)

    scale_out = range_out.max - range_out.min
    scale_in = range_in.max - range_in.min

    if scale_only:
        scaled_values = (values / scale_in) * scale_out
    else:
        scaled_values = (values - range_in.min) / scale_in
        scaled_values = (scaled_values * scale_out) + range_out.min

    return scaled_values


''' F2 '''
def F2(X):
    f = bn.F2()
    X = np.array(X)
    return f(X)

''' F3 '''
def F3(X):
    f = bn.F3()
    X = np.array(X)
    return f(X)

''' F7 '''
def F7(X):
    f = bn.F7()
    X = np.array(X)
    return f(X)

''' F9 '''
def F9(X):
    f = bn.F9()
    X = np.array(X)
    return f(X)

''' F10 '''
def F10(X):
    f = bn.F10()
    X = np.array(X)
    return f(X)

''' F13 '''
def F13(X):
    f = bn.F13()
    X = np.array(X)
    return f(X)

''' F15 '''
def F15(X):
    f = bn.F15()
    X = np.array(X)
    return f(X)

''' F16 '''
def F16(X):
    f = bn.F16()
    X = np.array(X)
    return f(X)

''' F20 '''
def F20(X):
    f = bn.F20()
    X = np.array(X)
    return f(X)

''' F24 '''
def F24(X):
    f = bn.F24()
    X = np.array(X)
    return f(X)

''' Latin HyperCube Sampling Design of Experiment '''
def DOE(n_obs, dim):
    np.random.seed(0)
    lhd = pyDOE.lhs(n=dim, samples=n_obs, criterion='m')
    X = [lhd[:,idx] for idx in range(dim)]
    return X

''' Kriging'''
def kriging(train_data,test_data):
    kernel =  RationalQuadratic()
    scaler = MinMaxScaler().fit(np.r_[train_data.iloc[:,:-1].values])
    gpr = GaussianProcessRegressor(kernel=kernel,n_restarts_optimizer= 15,random_state=0,
                                   normalize_y=True ).fit(scaler.transform(train_data.iloc[:,:-1]), train_data.iloc[:,-1])
    pred = gpr.predict(scaler.transform(test_data))
    def predict(scaler, gpr):
        def __predict__(x):
            x = np.atleast_2d(x)
            return gpr.predict(scaler.transform(x))
        return __predict__
    return gpr,pred, predict(scaler,gpr)

""" This method implements and evaluates the Kriging Surrogate Model with RMAE """
def surrogate_model(train_data,test_data):
    model_kri , pred_kri , predict_kri = kriging(train_data,test_data.iloc[:,:-1])
    return predict_kri

""" Implements all the surrogate models, i.e., for all test function, and returns the median of RMAE errors,
This median is used as the primary metric for Hyper-Parameters Optimization """
def perform_surrogate_modeling(paths):
    train_2, test_2, _ = load_f2(paths[0])
    predict_kri_2 = surrogate_model(train_2, test_2)
    
    train_3, test_3, _ = load_f3(paths[1])
    predict_kri_3 = surrogate_model(train_3, test_3)
    
    train_7, test_7, _ = load_f7(paths[2])
    predict_kri_7 = surrogate_model(train_7, test_7)
    
    train_9, test_9, _ = load_f9(paths[3])
    predict_kri_9 = surrogate_model(train_9, test_9)
    
    train_10, test_10, _ = load_f10(paths[4])
    predict_kri_10 = surrogate_model(train_10, test_10)
    
    train_13, test_13, _ = load_f13(paths[5])
    predict_kri_13 = surrogate_model(train_13, test_13)
    
    train_15, test_15, _ = load_f15(paths[6])
    predict_kri_15 = surrogate_model(train_15, test_15)
    
    train_16, test_16, _ = load_f16(paths[7])
    predict_kri_16 = surrogate_model(train_16, test_16)
    
    train_20, test_20, _ = load_f20(paths[8])
    predict_kri_20 = surrogate_model(train_20, test_20)
    
    train_24, test_24, _ = load_f24(paths[9])
    predict_kri_24 = surrogate_model(train_24, test_24)
    
    kri = [predict_kri_2,predict_kri_3,predict_kri_7,predict_kri_9,predict_kri_10,predict_kri_13,
          predict_kri_15,predict_kri_16,predict_kri_20,predict_kri_24]
    
    return kri
""" This is the function used for Hyper_Parameters_Optimization for both dimensionality reduction and surrogate modelling """
def run(paths):
    kri = perform_surrogate_modeling (paths)
    return kri

# %% [markdown]
# ## End Surrogate Modelling Code

# %% [markdown]
# ## Set Paths

# %%
# Change the Paths here depending upon the dimensionality {50D=1000,100D=2000,200D=4000} 
path_2 = "Data Generation/50 D/Training_Data_Sets/train_2_1000Samples.csv"
path_3 = "Data Generation/50 D/Training_Data_Sets/train_3_1000Samples.csv"
path_7 = "Data Generation/50 D/Training_Data_Sets/train_7_1000Samples.csv"
path_9 = "Data Generation/50 D/Training_Data_Sets/train_9_1000Samples.csv"
path_10 = "Data Generation/50 D/Training_Data_Sets/train_10_1000Samples.csv"
path_13 = "Data Generation/50 D/Training_Data_Sets/train_13_1000Samples.csv"
path_15 = "Data Generation/50 D/Training_Data_Sets/train_15_1000Samples.csv"
path_16 = "Data Generation/50 D/Training_Data_Sets/train_16_1000Samples.csv"
path_20 = "Data Generation/50 D/Training_Data_Sets/train_201000Samples.csv"
path_24 = "Data Generation/50 D/Training_Data_Sets/train_241000Samples.csv"
#  Change the Paths here depending upon the dimensionality {50D=1000,100D=2000,200D=4000} 
paths = [path_2,path_3,path_7,path_9,path_10,path_13,path_15,path_16,path_20,path_24]

# %% [markdown]
# ## Perform Dimensionality Reduction and Construct the Surrogate Models

# %%
kri = run(paths)

# %% [markdown]
# ## BFGS

# %%
dimensionality = int(50 - (0.3 * 50)) # change here
Columns = ['Kri']
Cols = []
for j in range(len(Columns)):
    for i in range(1,dimensionality+1):
        Cols.append(Columns[j]+'_Z'+str(i))
opt = {'maxfun':1000 * dimensionality,'ftol':0.0}
const = Bounds([-5] * dimensionality, [5] * dimensionality)        
n_obs =  30
G = DOE(n_obs, dimensionality)
G = [ G[idx].reshape(n_obs,1) for idx in range(len(G)) ]
X_2_Values = np.zeros([n_obs,dimensionality])
X_3_Values = np.zeros([n_obs,dimensionality])
X_7_Values = np.zeros([n_obs,dimensionality])
X_9_Values = np.zeros([n_obs,dimensionality])
X_10_Values = np.zeros([n_obs,dimensionality])
X_13_Values = np.zeros([n_obs,dimensionality])
X_15_Values = np.zeros([n_obs,dimensionality])
X_16_Values = np.zeros([n_obs,dimensionality])
X_20_Values = np.zeros([n_obs,dimensionality])
X_24_Values = np.zeros([n_obs,dimensionality])

for i in range(G[1].shape[0]):
    min_kri_2  = minimize(fun=kri[0], x0 = linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_3  = minimize(fun=kri[1],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_7  = minimize(fun=kri[2],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_9  = minimize(fun=kri[3],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_10  = minimize(fun=kri[4],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_13  = minimize(fun=kri[5],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_15  = minimize(fun=kri[6],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_16  = minimize(fun=kri[7],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_20  = minimize(fun=kri[8],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)
    min_kri_24  = minimize(fun=kri[9],x0=linearscaletransform(np.concatenate(G, 1)[i],range_out=(-5,5)),bounds=const, method='L-BFGS-B',options=opt)

    X_2_Values [i,:] = list(min_kri_2.x)
    X_3_Values [i,:] = list(min_kri_3.x)
    X_7_Values [i,:] = list(min_kri_7.x)
    X_9_Values [i,:] = list(min_kri_9.x)
    X_10_Values [i,:] = list(min_kri_10.x)                                           
    X_13_Values [i,:] = list(min_kri_13.x)
    X_15_Values [i,:] = list(min_kri_15.x)
    X_16_Values [i,:] = list(min_kri_16.x) 
    X_20_Values [i,:] = list(min_kri_20.x) 
    X_24_Values [i,:] = list(min_kri_24.x)
# Out:
# Run : 0
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=775969, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [55549696.62883809] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.14e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.554969662883809e+07 1.0e+00 1.14e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.14e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.14e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.14e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 5.554970e+07 5.554970e+07
# incumbent solution: [0.6505171268694689, 0.5610738224897065, 0.2732819306790441, 0.4000851083945524, 0.43721541891891874]
# std deviation: [0.11847102722397172, 0.10591496501516234, 0.11008084546272374, 0.1160162347097819, 0.10912299469302777]
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.14e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=781672, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [6482.88014905] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 6.482880149046558e+03 1.0e+00 1.08e-01  9e-02  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 6.482880e+03 6.482880e+03
# incumbent solution: [0.48904913279213313, 0.43176359268790754, 0.2290978126078901, 0.25735593123613903, 0.38676458897688915]
# std deviation: [0.10964997686731826, 0.10568375143847464, 0.09488280462920551, 0.1115496320076058, 0.10629561731002969]
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=729699, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [8716.84208835] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 8.716842088347912e+03 1.0e+00 1.22e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 8.716842e+03 8.716842e+03
# incumbent solution: [0.5880275470582631, 0.6250829759697392, 0.3587672375049488, 0.33646920682388104, 0.4132186983756561]
# std deviation: [0.1181503246086261, 0.1342988651054972, 0.12735298172189083, 0.1129164402565316, 0.11268977921642406]
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=715367, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [1060866.69046053] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.06e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 1.060866690460530e+06 1.0e+00 1.06e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.06e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.06e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.06e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 1.060867e+06 1.060867e+06
# incumbent solution: [0.527665218907059, 0.5630968412542927, 0.1854810868170062, 0.31160325635909114, 0.47197904266547364]
# std deviation: [0.10223398066447462, 0.10580510947800113, 0.1030062270471155, 0.10440031436581491, 0.10804175645885755]
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.06e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=741678, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [42185443.47732956] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 4.218544347732956e+07 1.0e+00 1.20e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 4.218544e+07 4.218544e+07
# incumbent solution: [0.4550710732848986, 0.3704616659398026, 0.27879367764639995, 0.2458103508706167, 0.3914466051362168]
# std deviation: [0.11917355474927724, 0.12765391955407773, 0.1148092911132272, 0.12065104272299038, 0.11808880373289798]
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=779131, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [5091.15147693] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.091151476932267e+03 1.0e+00 1.12e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 5.091151e+03 5.091151e+03
# incumbent solution: [0.5719894018650014, 0.6140600766065268, 0.19960592364617433, 0.36354380197055136, 0.43922346034232557]
# std deviation: [0.10590108779012584, 0.11576242101670703, 0.11531826413877524, 0.11190890864072033, 0.10528900330486438]
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=807114, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [6484.98840307] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 6.484988403065864e+03 1.0e+00 1.08e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 6.484988e+03 6.484988e+03
# incumbent solution: [0.6136138137034193, 0.4581192832789586, 0.1439262193734585, 0.3524474669786163, 0.4133705010890819]
# std deviation: [0.10639265193216285, 0.10252005632260831, 0.1113027198001369, 0.10592787212445945, 0.10295965726141836]
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.08e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=816834, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [-179.61112505] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 -1.796111250460871e+02 1.0e+00 1.17e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = -1.796111e+02 -1.796111e+02
# incumbent solution: [0.6640364427183733, 0.5827255515473537, 0.28272439079503775, 0.31883069697423794, 0.44743282874952217]
# std deviation: [0.12216295648853766, 0.11744536048106591, 0.11623652826166941, 0.1093641986737167, 0.11326351600079222]
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=818829, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [502874.37719072] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.028743771907234e+05 1.0e+00 1.09e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 5.028744e+05 5.028744e+05
# incumbent solution: [0.5627719935464783, 0.46408644616664857, 0.33323136367233247, 0.36155467844667344, 0.36798603270280644]
# std deviation: [0.10882295904146065, 0.10707899679283654, 0.10664840236357988, 0.10097764387344142, 0.10898820477139858]
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=800048, Mon Jul 13 16:31:50 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [2260.24107292] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.01e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 2.260241072922580e+03 1.0e+00 1.01e-01  9e-02  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.01e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.01e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.01e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:50 2020)
# final/bestever f-value = 2.260241e+03 2.260241e+03
# incumbent solution: [0.5716446666708315, 0.4604082820383227, 0.2552253214469256, 0.3731842251800825, 0.46395794464362194]
# std deviation: [0.10142525309583429, 0.09816843260465047, 0.09629795889788452, 0.09816848292664165, 0.09483225435702718]
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.01e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# Run : 1
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=746046, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [55549696.62883809] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.37e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.554969662883809e+07 1.0e+00 1.37e-01  1e-01  2e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.37e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.37e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.37e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 5.554970e+07 5.554970e+07
# incumbent solution: [0.18719499706903844, 0.6419354051622752, 0.5476005137592266, 0.2535470602130494, 0.35750875360023365]
# std deviation: [0.12930781693792928, 0.13981838500370264, 0.16429794938020256, 0.13373924601879633, 0.1374342031496362]
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.37e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=678595, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [6482.88014905] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 6.482880149046558e+03 1.0e+00 1.16e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 6.482880e+03 6.482880e+03
# incumbent solution: [0.28393898382014954, 0.5626011900797343, 0.7685470553684829, 0.22626208636652712, 0.14491234536356498]
# std deviation: [0.11463253955771455, 0.11202623201510557, 0.10784697364222397, 0.11211485272621985, 0.12429315108189334]
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=671963, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [8716.84208835] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 8.716842088347912e+03 1.0e+00 1.16e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 8.716842e+03 8.716842e+03
# incumbent solution: [0.31902423321140794, 0.4368228692713792, 0.7649744118101117, 0.34171757517999873, 0.3030050822989011]
# std deviation: [0.11624587027124407, 0.12134955020607852, 0.1084934542731286, 0.11574063336647873, 0.1186674759557768]
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.16e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=712051, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [1060866.69046053] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.15e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 1.060866690460530e+06 1.0e+00 1.15e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.15e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.15e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.15e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 1.060867e+06 1.060867e+06
# incumbent solution: [0.19015853184624712, 0.5073869413999854, 0.7657561165602235, 0.18468260305962148, 0.19298012208961868]
# std deviation: [0.12386754172374828, 0.11206416512928305, 0.1060711566547394, 0.11263767730219915, 0.11269914191760062]
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.15e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=749915, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [42185443.47732956] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 4.218544347732956e+07 1.0e+00 1.22e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 4.218544e+07 4.218544e+07
# incumbent solution: [0.33129997087610064, 0.48381267200541067, 0.8042431115850758, 0.39405111145195776, 0.28577923049627685]
# std deviation: [0.12300294358830581, 0.12522282555018363, 0.11625865630471478, 0.1331137580829253, 0.12208665105658581]
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.22e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=775576, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [5091.15147693] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.31e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.091151476932267e+03 1.0e+00 1.31e-01  1e-01  2e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.31e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.31e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.31e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 5.091151e+03 5.091151e+03
# incumbent solution: [0.07097090863985911, 0.5113434235255534, 0.6811824704639384, 0.23070422600122062, 0.3299176500940999]
# std deviation: [0.1572263100067749, 0.12199594302699507, 0.13123565596429387, 0.12396857877058959, 0.12939892169146877]
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.31e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=749404, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [6484.98840307] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 6.484988403065864e+03 1.0e+00 1.28e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 6.484988e+03 6.484988e+03
# incumbent solution: [0.23314874135103483, 0.6995519904210535, 0.686557489437979, 0.28602659400639463, 0.4020777596085106]
# std deviation: [0.12327483769385132, 0.1418860058695074, 0.12624687343364657, 0.1279805973328115, 0.127558630755597]
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=793269, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [-179.61112505] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.23e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 -1.796111250460871e+02 1.0e+00 1.23e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.23e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.23e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.23e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = -1.796111e+02 -1.796111e+02
# incumbent solution: [0.16247676662144866, 0.4526010202848282, 0.6407256523152494, 0.24506009185657776, 0.3215223342439767]
# std deviation: [0.12701155985568915, 0.12295918567430193, 0.12991638080510232, 0.12273637500843902, 0.11872985632184938]
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.23e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=759604, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [502874.37719072] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.11e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.028743771907234e+05 1.0e+00 1.11e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.11e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.11e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.11e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 5.028744e+05 5.028744e+05
# incumbent solution: [0.17870785535951833, 0.552283256093179, 0.7268016731590836, 0.2640089447563867, 0.27607069924463323]
# std deviation: [0.11460062919909768, 0.1081270583980824, 0.10998431549729526, 0.10621475173822467, 0.1001487178594432]
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.11e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=786134, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [2260.24107292] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.19e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 2.260241072922580e+03 1.0e+00 1.19e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.19e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.19e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.19e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 2.260241e+03 2.260241e+03
# incumbent solution: [0.41135997320113643, 0.4721478425686849, 0.8250704092337622, 0.30797426855285287, 0.30746391116276084]
# std deviation: [0.12051610650204392, 0.11322437480898838, 0.11890711886775335, 0.11699633578727757, 0.11899983094440948]
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.19e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# Run : 2
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=725151, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [55549696.62883809] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.554969662883809e+07 1.0e+00 1.20e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 5.554970e+07 5.554970e+07
# incumbent solution: [0.793456553240367, 0.6865869351888514, 0.4684838591080144, 0.419455592747071, 0.7421543950473908]
# std deviation: [0.11920642803329481, 0.1198195021827694, 0.12034159709556555, 0.1248062392378991, 0.1185071667542898]
# WARNING (iteration=1):  flat fitness (f=55549696.628838, sigma=1.20e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=806161, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [6482.88014905] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 6.482880149046558e+03 1.0e+00 1.12e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 6.482880e+03 6.482880e+03
# incumbent solution: [0.6781544551715538, 0.8468530502748386, 0.46641254697383644, 0.6068881445839008, 0.6211214854615963]
# std deviation: [0.1081997781403468, 0.11146942248688148, 0.11205595686147184, 0.114814002137537, 0.0984323072166987]
# WARNING (iteration=1):  flat fitness (f=6482.880149, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=740569, Mon Jul 13 16:31:51 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [8716.84208835] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 8.716842088347912e+03 1.0e+00 1.17e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.17e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:31:51 2020)
# final/bestever f-value = 8.716842e+03 8.716842e+03
# incumbent solution: [0.8370315486365962, 0.7680413387669323, 0.38542077819836834, 0.47516051614597615, 0.7552156233315828]
# ...
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = 8.716842e+03 8.716842e+03
# incumbent solution: [0.30628177425584824, 0.3629097004135664, 1.0487428570516388, 0.8513495895396117, 0.6427776514010628]
# std deviation: [0.10719508873489123, 0.11378554984267678, 0.11169131706190136, 0.10597313605993947, 0.11930921383215866]
# WARNING (iteration=1):  flat fitness (f=8716.842088, sigma=1.12e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=785601, Mon Jul 13 16:32:10 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [1060866.69046053] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 1.060866690460530e+06 1.0e+00 1.28e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = 1.060867e+06 1.060867e+06
# incumbent solution: [0.17837814916645442, 0.2978089386217315, 0.9355007905920181, 0.7868271997509049, 0.6748960161933554]
# std deviation: [0.13766483964303655, 0.13864225381701037, 0.12202961240093216, 0.1255058926195728, 0.1219622463153727]
# WARNING (iteration=1):  flat fitness (f=1060866.690461, sigma=1.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=743502, Mon Jul 13 16:32:10 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [42185443.47732956] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.40e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 4.218544347732956e+07 1.0e+00 1.40e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.40e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.40e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.40e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = 4.218544e+07 4.218544e+07
# incumbent solution: [0.48273715726931005, 0.45338767142030895, 1.1694503533979457, 0.9112623797480176, 0.750626734169806]
# std deviation: [0.14263048714867388, 0.13435516540225728, 0.14408099440391453, 0.14262402386117162, 0.14368828677038079]
# WARNING (iteration=1):  flat fitness (f=42185443.477330, sigma=1.40e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=775469, Mon Jul 13 16:32:10 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [5091.15147693] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.091151476932267e+03 1.0e+00 1.04e-01  9e-02  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = 5.091151e+03 5.091151e+03
# incumbent solution: [0.3599477078578038, 0.43786735809017907, 1.0032468815730098, 0.8270615406378428, 0.5906000080990207]
# std deviation: [0.09493921243495368, 0.10386312886715587, 0.09817743330065147, 0.10119036870689757, 0.10268172834307125]
# WARNING (iteration=1):  flat fitness (f=5091.151477, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=789363, Mon Jul 13 16:32:10 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [6484.98840307] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.35e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 6.484988403065864e+03 1.0e+00 1.35e-01  1e-01  2e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.35e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.35e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.35e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = 6.484988e+03 6.484988e+03
# incumbent solution: [0.5801852286754462, 0.4418313449766894, 0.8727864995398477, 0.7622920511519443, 0.5710245080583431]
# std deviation: [0.1620781023872628, 0.13879115116921611, 0.1283904724324968, 0.12095744387828829, 0.1435307081309185]
# WARNING (iteration=1):  flat fitness (f=6484.988403, sigma=1.35e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=780901, Mon Jul 13 16:32:10 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [-179.61112505] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 -1.796111250460871e+02 1.0e+00 1.09e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = -1.796111e+02 -1.796111e+02
# incumbent solution: [0.3735125314341992, 0.403535103841667, 1.0412416946159548, 0.8710794907610359, 0.6207422192374519]
# std deviation: [0.10820264500225116, 0.10323993878981363, 0.10708761333862911, 0.10630922046224615, 0.10624169683024082]
# WARNING (iteration=1):  flat fitness (f=-179.611125, sigma=1.09e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=788425, Mon Jul 13 16:32:10 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [502874.37719072] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.26e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 5.028743771907234e+05 1.0e+00 1.26e-01  1e-01  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.26e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.26e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.26e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = 5.028744e+05 5.028744e+05
# incumbent solution: [0.25497402346871256, 0.4262981378103359, 0.8228545810601136, 0.9109011059562471, 0.7214035048292811]
# std deviation: [0.1295561545273299, 0.12330794186608895, 0.1277469162335474, 0.12982825788618738, 0.1224328367599466]
# WARNING (iteration=1):  flat fitness (f=502874.377191, sigma=1.26e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 5 (seed=808536, Mon Jul 13 16:32:10 2020)
# WARNING ():  function_values is not a list of scalars,
#                         the first element equals [2260.24107292] with non-scalar type <class 'numpy.ndarray'>.
#                         Using now ``[v[0] for v in function_values]`` instead (further warnings are suppressed)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#     1      8 2.260241072922580e+03 1.0e+00 1.04e-01  9e-02  1e-01 0:00.0
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11 (Mon Jul 13 16:32:10 2020)
# final/bestever f-value = 2.260241e+03 2.260241e+03
# incumbent solution: [0.287186422630163, 0.3947182685244255, 0.9570318205430017, 0.7771653152919695, 0.6928931986655537]
# std deviation: [0.10805751443853316, 0.10064236170922113, 0.09200512451136265, 0.10827524829452519, 0.10118671719691635]
# WARNING (iteration=1):  flat fitness (f=2260.241073, sigma=1.04e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.

# %%
X_2_Values = pd.DataFrame(X_2_Values)
X_2_Values.columns = Cols
X_2_Values.to_csv('F2_X_Values.csv')

X_3_Values = pd.DataFrame(X_3_Values)
X_3_Values.columns = Cols
X_3_Values.to_csv('F3_X_Values.csv')

X_7_Values = pd.DataFrame(X_7_Values)
X_7_Values.columns = Cols
X_7_Values.to_csv('F7_X_Values.csv')

X_9_Values = pd.DataFrame(X_9_Values)
X_9_Values.columns = Cols
X_9_Values.to_csv('F9_X_Values.csv')

X_10_Values = pd.DataFrame(X_10_Values)
X_10_Values.columns = Cols
X_10_Values.to_csv('F10_X_Values.csv')

X_13_Values = pd.DataFrame(X_13_Values)
X_13_Values.columns = Cols
X_13_Values.to_csv('F13_X_Values.csv')

X_15_Values = pd.DataFrame(X_15_Values)
X_15_Values.columns = Cols
X_15_Values.to_csv('F15_X_Values.csv')

X_16_Values = pd.DataFrame(X_16_Values)
X_16_Values.columns = Cols
X_16_Values.to_csv('F16_X_Values.csv')

X_20_Values = pd.DataFrame(X_20_Values)
X_20_Values.columns = Cols
X_20_Values.to_csv('F20_X_Values.csv')

X_24_Values = pd.DataFrame(X_24_Values)
X_24_Values.columns = Cols
X_24_Values.to_csv('F24_X_Values.csv')


Krig_Fun_2 = np.zeros(30)
Krig_Fun_3 = np.zeros(30)
Krig_Fun_7 = np.zeros(30)
Krig_Fun_9 = np.zeros(30)
Krig_Fun_10 = np.zeros(30)
Krig_Fun_13 = np.zeros(30)
Krig_Fun_15 = np.zeros(30)
Krig_Fun_16 = np.zeros(30)
Krig_Fun_20 = np.zeros(30)
Krig_Fun_24 = np.zeros(30)
for i in range(X_2_Values.shape[0]):
    Krig_Fun_2 [i] = F2(X_2_Values.iloc[i,:])
    Krig_Fun_3 [i] = F3(X_3_Values.iloc[i,:])
    Krig_Fun_7 [i] = F7(X_7_Values.iloc[i,:])
    Krig_Fun_9 [i] = F9(X_9_Values.iloc[i,:])
    Krig_Fun_10 [i] = F10(X_10_Values.iloc[i,:])
    Krig_Fun_13 [i] = F13(X_13_Values.iloc[i,:])
    Krig_Fun_15 [i] = F15(X_15_Values.iloc[i,:])
    Krig_Fun_16 [i] = F16(X_16_Values.iloc[i,:])
    Krig_Fun_20 [i] = F20(X_20_Values.iloc[i,:])
    Krig_Fun_24 [i] = F24(X_24_Values.iloc[i,:])
    

print ('Kriging-f2')
print (np.median(Krig_Fun_2) )
print ('Kriging-f3')
print (np.median(Krig_Fun_3) )
print ('Kriging-f7')
print (np.median(Krig_Fun_7) )
print ('Kriging-f9')
print (np.median(Krig_Fun_9) )
print ('Kriging-f10')
print (np.median(Krig_Fun_10) )
print ('Kriging-f13')
print (np.median(Krig_Fun_13) )
print ('Kriging-f15')
print (np.median(Krig_Fun_15) )
print ('Kriging-f16')
print (np.median(Krig_Fun_16) )
print ('Kriging-f20')
print (np.median(Krig_Fun_20) )
print ('Kriging-f24')
print (np.median(Krig_Fun_24))

# %%
np.array([np.median(Krig_Fun_2),np.median(Krig_Fun_3),np.median(Krig_Fun_7),np.median(Krig_Fun_9),
np.median(Krig_Fun_10),np.median(Krig_Fun_13),np.median(Krig_Fun_15),np.median(Krig_Fun_16),
np.median(Krig_Fun_20),np.median(Krig_Fun_24)])
